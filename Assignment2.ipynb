# %% [markdown]
# #Q.1

# %%
for i in range(1,10):
     if i>5:
        i=10-i
     print(i*" *")
# Out:
#  *
#  * *
#  * * *
#  * * * *
#  * * * * *
#  * * * *
#  * * *
#  * *
#  *

# %% [markdown]
# #Q.2

# %%
a = input("Enter word: ")
print(a[::-1])
# Out:
# Enter word: ineuron
# norueni

# %%
b = input("Enter word: ")
c = ''
index = len(b)
while index>0:
  c = c + b[index-1]
  index = index-1
  
print(c)
# Out:
# Enter word: Pratik
# kitarP
